# %% [markdown]
# # Latent Semantic Analysis

# %% [markdown]
# ### Latent semantic analysis & topic models
#
# The LSA approach makes three claims:
#
# 1. semantic information can be derived from a word-document co-occurrence matrix
# 2. dimensionality reduction is an essential part of this derivation
# 3. words and documents can be represented as points in Euclidean space

# %% [markdown]
# ### Singular Value Decomposition
#
# - Factors matrix into the product of three matrices
#
#   $$X = USV^T$$
#
# - $m$ is the number of documents
# - $n$ is the number of terms
# - $U$ is $m\times n$
# - $S$ is $n\times n$
# - $V$ is $n\times n$

# %% [markdown]
# ### Low-Rank Approximation Singular Value Decomposition
#
# - Factors matrix into the product of three matrices
#
#   $$X = U_kS_kV_k^T$$
#
# - $m$ is the number of documents
# - $n$ is the number of terms
# - $k$ is the number of concepts
# - $U_k$ is $m\times k$
# - $S_k$ is $k\times k$
# - $V_k$ is $k\times n$

# %% [markdown]
# ![](https://www.evernote.com/l/AAFB4YtgyxdKJ7ZEJnQHmzfSfIFTiKySqMUB/image.png)

# %% [markdown]
# ### Interpret Results
#
# What are the top "concepts"?
#
# What dimensions in term-space and document-space explain most of the variance in the data?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
corpus = pd.read_pickle('news.p')

# %%
corpus.columns
# Out:
# Index(['text', 'group_num', 'group'], dtype='object')

# %%
corpus['group'].unique()
# Out:
# array(['rec.autos', 'comp.sys.mac.hardware', 'comp.graphics', 'sci.space',
#        'talk.politics.guns', 'sci.med', 'comp.sys.ibm.pc.hardware',
#        'comp.os.ms-windows.misc', 'rec.motorcycles', 'talk.religion.misc',
#        'misc.forsale', 'alt.atheism', 'sci.electronics', 'comp.windows.x',
#        'rec.sport.hockey', 'rec.sport.baseball', 'soc.religion.christian',
#        'talk.politics.mideast', 'talk.politics.misc', 'sci.crypt'], dtype=object)

# %%
le = LabelEncoder()
corpus['group_num'] = le.fit_transform(corpus['group'])

# %%
corpus.head()
# Out:
#                                                 text  group_num  \
# 0  From: lerxst@wam.umd.edu (where's my thing)\nS...          7
# 1  From: guykuo@carson.u.washington.edu (Guy Kuo)...          4
# 2  From: twillis@ec.ecn.purdue.edu (Thomas E Will...          4
# 3  From: jgreen@amber (Joe Green)\nSubject: Re: W...          1
# 4  From: jcm@head-cfa.harvard.edu (Jonathan McDow...         14
#
#                    group
# 0              rec.autos
# 1  comp.sys.mac.hardware
# 2  comp.sys.mac.hardware
# 3          comp.graphics
# 4              sci.space

# %%
def create_document_term_matrix(vectorizer, corpus):
    document_term_matrix = vectorizer.fit_transform(corpus)
    document_term_matrix = pd.DataFrame(document_term_matrix.toarray(),
                                        index=corpus,
                                        columns=vectorizer.get_feature_names ())
    return document_term_matrix

# %%
naive_vectorizer = CountVectorizer(min_df = 1, stop_words = 'english')
document_term_matrix = create_document_term_matrix(naive_vectorizer, corpus['text'])
document_term_matrix.head()
# Out:
#                                                     00  000  0000  00000  \
# text
# From: lerxst@wam.umd.edu (where's my thing)\nSu...   0    0     0      0
# From: guykuo@carson.u.washington.edu (Guy Kuo)\...   0    0     0      0
# From: twillis@ec.ecn.purdue.edu (Thomas E Willi...   0    0     0      0
# From: jgreen@amber (Joe Green)\nSubject: Re: We...   0    0     0      0
# From: jcm@head-cfa.harvard.edu (Jonathan McDowe...   0    0     0      0
#
#                                                     000000  00000000  \
# text
# From: lerxst@wam.umd.edu (where's my thing)\nSu...       0         0
# From: guykuo@carson.u.washington.edu (Guy Kuo)\...       0         0
# From: twillis@ec.ecn.purdue.edu (Thomas E Willi...       0         0
# From: jgreen@amber (Joe Green)\nSubject: Re: We...       0         0
# From: jcm@head-cfa.harvard.edu (Jonathan McDowe...       0         0
#
#                                                     0000000004  0000000005  \
# text
# From: lerxst@wam.umd.edu (where's my thing)\nSu...           0           0
# From: guykuo@carson.u.washington.edu (Guy Kuo)\...           0           0
# From: twillis@ec.ecn.purdue.edu (Thomas E Willi...           0           0
# From: jgreen@amber (Joe Green)\nSubject: Re: We...           0           0
# From: jcm@head-cfa.harvard.edu (Jonathan McDowe...           0           0
#
#                                                     00000000b  00000001 ...  \
# text                                                                    ...
# From: lerxst@wam.umd.edu (where's my thing)\nSu...          0         0 ...
# From: guykuo@carson.u.washington.edu (Guy Kuo)\...          0         0 ...
# From: twillis@ec.ecn.purdue.edu (Thomas E Willi...          0         0 ...
# From: jgreen@amber (Joe Green)\nSubject: Re: We...          0         0 ...
# From: jcm@head-cfa.harvard.edu (Jonathan McDowe...          0         0 ...
#
#                                                     çon  ère  ée  égligent  \
# text
# From: lerxst@wam.umd.edu (where's my thing)\nSu...    0    0   0         0
# From: guykuo@carson.u.washington.edu (Guy Kuo)\...    0    0   0         0
# From: twillis@ec.ecn.purdue.edu (Thomas E Willi...    0    0   0         0
# From: jgreen@amber (Joe Green)\nSubject: Re: We...    0    0   0         0
# From: jcm@head-cfa.harvard.edu (Jonathan McDowe...    0    0   0         0
#
#                                                     élangea  érale  ête  \
# text
# From: lerxst@wam.umd.edu (where's my thing)\nSu...        0      0    0
# From: guykuo@carson.u.washington.edu (Guy Kuo)\...        0      0    0
# From: twillis@ec.ecn.purdue.edu (Thomas E Willi...        0      0    0
# From: jgreen@amber (Joe Green)\nSubject: Re: We...        0      0    0
# From: jcm@head-cfa.harvard.edu (Jonathan McDowe...        0      0    0
#
#                                                     íålittin  ñaustin  ýé
# text
# From: lerxst@wam.umd.edu (where's my thing)\nSu...         0        0   0
# From: guykuo@carson.u.washington.edu (Guy Kuo)\...         0        0   0
# From: twillis@ec.ecn.purdue.edu (Thomas E Willi...         0        0   0
# From: jgreen@amber (Joe Green)\nSubject: Re: We...         0        0   0
# From: jcm@head-cfa.harvard.edu (Jonathan McDowe...         0        0   0
#
# [5 rows x 129796 columns]

# %%
def perform_latent_semantic_analysis(n_components, vectorizer):
    SVD = TruncatedSVD(n_components)
    component_names = ["component_"+str(i+1) for i in range(n_components)]
    latent_semantic_analysis = pd.DataFrame(SVD.fit_transform(document_term_matrix),
                                            index = corpus.index,
                                            columns = component_names)
    vocabulary_expression = pd.DataFrame(SVD.components_,
                                         index = component_names,
                                         columns = vectorizer.get_feature_names())
    return latent_semantic_analysis, vocabulary_expression

# %%
latent_semantic_analysis, vocabulary_expression = perform_latent_semantic_analysis(2, naive_vectorizer)
latent_semantic_analysis['text'] = corpus['text']
latent_semantic_analysis['group'] = corpus['group']

# %%
latent_semantic_analysis.sample(10)
# Out:
#       component_1  component_2  \
# 1304     0.001302     0.381984
# 4015     0.000753     0.121650
# 82       0.004945     0.484823
# 8757     0.001124     0.161127
# 4675     0.004281     0.202306
# 932      0.001081     0.109478
# 7048     0.000785     0.094934
# 3840     0.001674     0.198992
# 7847     0.001137     0.279024
# 5347     0.000899     0.452947
#
#                                                    text  \
# 1304  From: dla@se05.wg2.waii.com (Doug Acker)\nSubj...
# 4015  From: adykes@jpradley.jpr.com (Al Dykes)\nSubj...
# 82    From: edb@dmssyd.syd.dms.CSIRO.AU (Ed Breen)\n...
# 8757  From: gerard@dps.co.UK (Gerard O'Driscoll)\nSu...
# 4675  From: km@cs.pitt.edu (Ken Mitchum)\nSubject: R...
# 932   From: pgf5@cunixa.cc.columbia.edu (Peter Garfi...
# 7048  From: demon@desire.wright.edu (Not a Boomer)\n...
# 3840  From: phoenix.Princeton.EDU!carlosn (Carlos G....
# 7847  From: cs89mcd@brunel.ac.uk (Michael C Davis)\n...
# 5347  From: jls@atglab.atg.com (Jerome Schneider)\nR...
#
#                          group
# 1304            comp.windows.x
# 4015  comp.sys.ibm.pc.hardware
# 82               comp.graphics
# 8757            comp.windows.x
# 4675                   sci.med
# 932      talk.politics.mideast
# 7048        talk.politics.misc
# 3840                 sci.space
# 7847    soc.religion.christian
# 5347   comp.os.ms-windows.misc

# %%
vocabulary_expression.abs().T.sort_values('component_1', ascending=False).head(10)
# Out:
#      component_1  component_2
# ax      0.996868     0.026535
# max     0.071637     0.014042
# g9v     0.016118     0.311519
# b8f     0.011657     0.339989
# a86     0.010404     0.348425
# pl      0.008974     0.117576
# 1d9     0.006563     0.208559
# 1t      0.006320     0.068727
# 145     0.006225     0.365923
# bhj     0.005682     0.059626

# %%
vocabulary_expression.abs().T.sort_values('component_2', ascending=False).head(10)
# Out:
#      component_1  component_2
# 145     0.006225     0.365923
# a86     0.010404     0.348425
# b8f     0.011657     0.339989
# 0d      0.002438     0.325778
# g9v     0.016118     0.311519
# 1d9     0.006563     0.208559
# 0t      0.004550     0.198135
# 2di     0.003780     0.177374
# _o      0.000145     0.175996
# 34u     0.004378     0.167505

# %%
plt.figure(figsize=(6,6))
pc_1 = latent_semantic_analysis['component_1'].values
pc_2 = latent_semantic_analysis['component_2'].values

plt.scatter(pc_1, pc_2, c=corpus['group_num'])

plt.xlabel('First PC')
plt.ylabel('Second PC')
plt.axvline(linewidth=0.5)
plt.axhline(linewidth=0.5)
plt.xlim(-.1,3)
plt.ylim(-.1,3)
# Out:
# (-0.1, 3)

# %%
tfidf_vectorizer = TfidfVectorizer(min_df = 1, stop_words = 'english')
document_term_matrix = create_document_term_matrix(tfidf_vectorizer, corpus['group'])
document_term_matrix.head()
# Out:
#                        alt  atheism     autos  baseball  christian      comp  \
# group
# rec.autos              0.0      0.0  0.839378       0.0        0.0  0.000000
# comp.sys.mac.hardware  0.0      0.0  0.000000       0.0        0.0  0.359505
# comp.sys.mac.hardware  0.0      0.0  0.000000       0.0        0.0  0.359505
# comp.graphics          0.0      0.0  0.000000       0.0        0.0  0.509919
# sci.space              0.0      0.0  0.000000       0.0        0.0  0.000000
#
#                        crypt  electronics  forsale  graphics   ...     \
# group                                                          ...
# rec.autos                0.0          0.0      0.0  0.000000   ...
# comp.sys.mac.hardware    0.0          0.0      0.0  0.000000   ...
# comp.sys.mac.hardware    0.0          0.0      0.0  0.000000   ...
# comp.graphics            0.0          0.0      0.0  0.860222   ...
# sci.space                0.0          0.0      0.0  0.000000   ...
#
#                        politics       rec  religion       sci  soc     space  \
# group
# rec.autos                   0.0  0.543548       0.0  0.000000  0.0  0.000000
# comp.sys.mac.hardware       0.0  0.000000       0.0  0.000000  0.0  0.000000
# comp.sys.mac.hardware       0.0  0.000000       0.0  0.000000  0.0  0.000000
# comp.graphics               0.0  0.000000       0.0  0.000000  0.0  0.000000
# sci.space                   0.0  0.000000       0.0  0.544391  0.0  0.838832
#
#                        sport       sys  talk  windows
# group
# rec.autos                0.0  0.000000   0.0      0.0
# comp.sys.mac.hardware    0.0  0.500513   0.0      0.0
# comp.sys.mac.hardware    0.0  0.500513   0.0      0.0
# comp.graphics            0.0  0.000000   0.0      0.0
# sci.space                0.0  0.000000   0.0      0.0
#
# [5 rows x 32 columns]

# %%
latent_semantic_analysis, vocabulary_expression = perform_latent_semantic_analysis(2, tfidf_vectorizer)
latent_semantic_analysis['text'] = corpus['text']
latent_semantic_analysis['group'] = corpus['group']

# %%
vocabulary_expression.abs().T.sort_values('component_1', ascending=False).head(10)
# Out:
#           component_1  component_2
# talk         0.524576     0.314342
# politics     0.464163     0.293963
# misc         0.430730     0.054727
# comp         0.294724     0.581443
# windows      0.232530     0.368590
# mideast      0.195314     0.137334
# guns         0.187902     0.132141
# religion     0.145972     0.067541
# forsale      0.132535     0.019711
# ms           0.118109     0.125447

# %%
vocabulary_expression.abs().T.sort_values('component_2', ascending=False).head(10)
# Out:
#           component_1  component_2
# comp         0.294724     0.581443
# windows      0.232530     0.368590
# talk         0.524576     0.314342
# politics     0.464163     0.293963
# hardware     0.103735     0.270305
# sys          0.103735     0.270305
# graphics     0.088561     0.204860
# mac          0.068872     0.178306
# pc           0.056857     0.149303
# ibm          0.056857     0.149303

# %%
plt.figure(figsize=(6,6))
pc_1 = latent_semantic_analysis['component_1'].values
pc_2 = latent_semantic_analysis['component_2'].values

plt.scatter(pc_1, pc_2, c=corpus['group_num'])

plt.xlabel('First PC')
plt.ylabel('Second PC')
plt.axvline(linewidth=0.5)
plt.axhline(linewidth=0.5)
plt.xlim(-.1,1)
plt.ylim(-.1,1)
# Out:
# (-0.1, 1)

# %%
latent_semantic_analysis.head()
# Out:
#    component_1  component_2  \
# 0    -0.001027    -0.001317
# 1     0.251648     0.587962
# 2     0.251648     0.587962
# 3     0.226382     0.472594
# 4    -0.001052    -0.000109
#
#                                                 text                  group
# 0  From: lerxst@wam.umd.edu (where's my thing)\nS...              rec.autos
# 1  From: guykuo@carson.u.washington.edu (Guy Kuo)...  comp.sys.mac.hardware
# 2  From: twillis@ec.ecn.purdue.edu (Thomas E Will...  comp.sys.mac.hardware
# 3  From: jgreen@amber (Joe Green)\nSubject: Re: W...          comp.graphics
# 4  From: jcm@head-cfa.harvard.edu (Jonathan McDow...              sci.space

# %%
latent_semantic_analysis['text'] = corpus['text']
latent_semantic_analysis[(latent_semantic_analysis['group'] == 'comp.sys.mac.hardware') 
                         & (latent_semantic_analysis['component_2'] > 0.58)]
# Out:
#        component_1  component_2  \
# 1         0.251648     0.587962
# 2         0.251648     0.587962
# 9         0.251648     0.587962
# 12        0.251648     0.587962
# 24        0.251648     0.587962
# 41        0.251648     0.587962
# 45        0.251648     0.587962
# 46        0.251648     0.587962
# 62        0.251648     0.587962
# 103       0.251648     0.587962
# 111       0.251648     0.587962
# 122       0.251648     0.587962
# 154       0.251648     0.587962
# 155       0.251648     0.587962
# 184       0.251648     0.587962
# 189       0.251648     0.587962
# 194       0.251648     0.587962
# 214       0.251648     0.587962
# 217       0.251648     0.587962
# 242       0.251648     0.587962
# 243       0.251648     0.587962
# 277       0.251648     0.587962
# 285       0.251648     0.587962
# 293       0.251648     0.587962
# 305       0.251648     0.587962
# 309       0.251648     0.587962
# 357       0.251648     0.587962
# 358       0.251648     0.587962
# 368       0.251648     0.587962
# 374       0.251648     0.587962
# ...            ...          ...
# 10766     0.251648     0.587962
# 10798     0.251648     0.587962
# 10804     0.251648     0.587962
# 10820     0.251648     0.587962
# 10856     0.251648     0.587962
# 10858     0.251648     0.587962
# 10889     0.251648     0.587962
# 10893     0.251648     0.587962
# 10935     0.251648     0.587962
# 10956     0.251648     0.587962
# 10974     0.251648     0.587962
# 10988     0.251648     0.587962
# 10994     0.251648     0.587962
# 10996     0.251648     0.587962
# 10999     0.251648     0.587962
# 11001     0.251648     0.587962
# 11022     0.251648     0.587962
# 11032     0.251648     0.587962
# 11040     0.251648     0.587962
# 11075     0.251648     0.587962
# 11080     0.251648     0.587962
# 11126     0.251648     0.587962
# 11175     0.251648     0.587962
# 11205     0.251648     0.587962
# 11226     0.251648     0.587962
# 11237     0.251648     0.587962
# 11284     0.251648     0.587962
# 11290     0.251648     0.587962
# 11303     0.251648     0.587962
# 11310     0.251648     0.587962
#
#                                                     text  \
# 1      From: guykuo@carson.u.washington.edu (Guy Kuo)...
# 2      From: twillis@ec.ecn.purdue.edu (Thomas E Will...
# 9      From: kerr@ux1.cso.uiuc.edu (Stan Kerr)\nSubje...
# 12     From: rodc@fc.hp.com (Rod Cerkoney)\nSubject: ...
# 24     From: nodine@lcs.mit.edu (Mark H. Nodine)\nSub...
# 41     From: root@ncube.com (Operator)\nSubject: Re: ...
# 45     From: Robert Everett Brunskill <rb6t+@andrew.c...
# 46     From: vng@iscs.nus.sg\nSubject: Wyse 60 Termin...
# 62     From: billd@informix.com (William Daul)\nSubje...
# 103    From: horton@molbio.cbs.umn.edu (Robert Horton...
# 111    From: sukenick@sci.ccny.cuny.edu (SYG)\nSubjec...
# 122    From: hades@coos.dartmouth.edu (Brian V. Hughe...
# 154    From: kssimon@silver.ucs.indiana.edu (kenneth ...
# 155    From: st890123@pip.cc.brandeis.edu (Joe Dropki...
# 184    From: guykuo@carson.u.washington.edu (Guy Kuo)...
# 189    From: kssimon@silver.ucs.indiana.edu (kenneth ...
# 194    From: lreiter@jade.tufts.edu (Lowell B. Reiter...
# 214    From: rick@howtek.MV.COM (Rick Roy)\nSubject: ...
# 217    Subject: Re: Mac OS on a 486!!! \nFrom: Keith ...
# 242    From: aris@psssun (Aris Gerakis)\nSubject: Pix...
# 243    From: d2cheng@undergrad.math.uwaterloo.ca (Dom...
# 277    From: gcohen@mailer.acns.fsu.edu (Gregory Cohe...
# 285    From: ab220@Freenet.carleton.ca (Michel Dozois...
# 293    From: jenski@cae.wisc.edu (Anders Jenski)\nSub...
# 305    From: Michael.Ameres@f204.n2603.z1.fidonet.org...
# 309    From: dashley@wyvern.wyvern.com (Doug Ashley)\...
# 357    From: leapman@austin.ibm.com (Scott Leapman)\n...
# 358    From: gpb@gpb-mac (greg berryman )\nSubject: R...
# 368    From: lau@aerospace.aero.org (David Lau)\nSubj...
# 374    From: rvenkate@ux4.cso.uiuc.edu (Ravikuma Venk...
# ...                                                  ...
# 10766  From: HK.MLR@forsythe.stanford.edu (Mark Rogow...
# 10798  From: mspace@netcom.com (Brian Hall)\nSubject:...
# 10804  From: HK.MLR@forsythe.stanford.edu (Mark Rogow...
# 10820  From: ray@netcom.com (Ray Fischer)\nSubject: R...
# 10856  From: lumpkin@corvus.nas.nasa.gov (Forrest E. ...
# 10858  From: kiran@village.com (Kiran Wagle)\nSubject...
# 10889  From: CM51@lafibm.lafayette.edu (CM51)\nSubjec...
# 10893  From: abravo@mondrian.CSUFresno.EDU (Andrew Br...
# 10935  From: rrn@po.CWRU.Edu (Robert R. Novitskey)\nS...
# 10956  From: d88-jwa@eufrat.nada.kth.se (Jon Wätte)\n...
# 10974  From: slang@bnr.ca (Steven Langlois)\nSubject:...
# 10988  From: kitchel@manta.dpsi.com (Sidney W. Kitche...
# 10994  From: avery@gestalt.Stanford.EDU (Avery Wang)\...
# 10996  From: bruceg@ccwf.cc.utexas.edu (Bruce Gimble)...
# 10999  From: hades@coos.dartmouth.edu (Brian V. Hughe...
# 11001  From: dark1@netcom.com (Steven Seeger)\nSubjec...
# 11022  From: d88-jwa@hemul.nada.kth.se (Jon Wtte)\nSu...
# 11032  From: horton@what.sps.mot.com (David Horton)\n...
# 11040  From: cherkaue@ee.rochester.edu (Brian Cherkau...
# 11075  From: akhiani@ricks.enet.dec.com (Homayoon Akh...
# 11080  From: daves@xetron.com (Dave Steele)\nSubject:...
# 11126  From: haase@meediv.lanl.gov (Peter Haase)\nSub...
# 11175  From: donovan@bnr.ca (Marc Donovan)\nSubject: ...
# 11205  From: eapu174@orion.oac.uci.edu (Wayne Chen)\n...
# 11226  From: wlyle@sju.edu (Wayne Lyle)\nSubject: Dri...
# 11237  From: ccw@lancelot.NoSubdomain.NoDomain (Chris...
# 11284  Distribution: world\nFrom: elenay_creations@tc...
# 11290  From: hades@coos.dartmouth.edu (Brian V. Hughe...
# 11303  From: bchuang@css.itd.umich.edu (Ben Chuang)\n...
# 11310  From: ebodin@pearl.tufts.edu\nSubject: Screen ...
#
#                        group
# 1      comp.sys.mac.hardware
# 2      comp.sys.mac.hardware
# 9      comp.sys.mac.hardware
# 12     comp.sys.mac.hardware
# 24     comp.sys.mac.hardware
# 41     comp.sys.mac.hardware
# 45     comp.sys.mac.hardware
# 46     comp.sys.mac.hardware
# 62     comp.sys.mac.hardware
# 103    comp.sys.mac.hardware
# 111    comp.sys.mac.hardware
# 122    comp.sys.mac.hardware
# 154    comp.sys.mac.hardware
# 155    comp.sys.mac.hardware
# 184    comp.sys.mac.hardware
# 189    comp.sys.mac.hardware
# 194    comp.sys.mac.hardware
# 214    comp.sys.mac.hardware
# 217    comp.sys.mac.hardware
# 242    comp.sys.mac.hardware
# 243    comp.sys.mac.hardware
# 277    comp.sys.mac.hardware
# 285    comp.sys.mac.hardware
# 293    comp.sys.mac.hardware
# 305    comp.sys.mac.hardware
# 309    comp.sys.mac.hardware
# 357    comp.sys.mac.hardware
# 358    comp.sys.mac.hardware
# 368    comp.sys.mac.hardware
# 374    comp.sys.mac.hardware
# ...                      ...
# 10766  comp.sys.mac.hardware
# 10798  comp.sys.mac.hardware
# 10804  comp.sys.mac.hardware
# 10820  comp.sys.mac.hardware
# 10856  comp.sys.mac.hardware
# 10858  comp.sys.mac.hardware
# 10889  comp.sys.mac.hardware
# 10893  comp.sys.mac.hardware
# 10935  comp.sys.mac.hardware
# 10956  comp.sys.mac.hardware
# 10974  comp.sys.mac.hardware
# 10988  comp.sys.mac.hardware
# 10994  comp.sys.mac.hardware
# 10996  comp.sys.mac.hardware
# 10999  comp.sys.mac.hardware
# 11001  comp.sys.mac.hardware
# 11022  comp.sys.mac.hardware
# 11032  comp.sys.mac.hardware
# 11040  comp.sys.mac.hardware
# 11075  comp.sys.mac.hardware
# 11080  comp.sys.mac.hardware
# 11126  comp.sys.mac.hardware
# 11175  comp.sys.mac.hardware
# 11205  comp.sys.mac.hardware
# 11226  comp.sys.mac.hardware
# 11237  comp.sys.mac.hardware
# 11284  comp.sys.mac.hardware
# 11290  comp.sys.mac.hardware
# 11303  comp.sys.mac.hardware
# 11310  comp.sys.mac.hardware
#
# [578 rows x 4 columns]

# %%
latent_semantic_analysis[(latent_semantic_analysis['group'] == 'comp.graphics') 
                         & (latent_semantic_analysis['component_1'] > .22)]
# Out:
#        component_1  component_2  \
# 3         0.226382     0.472594
# 16        0.226382     0.472594
# 25        0.226382     0.472594
# 82        0.226382     0.472594
# 87        0.226382     0.472594
# 99        0.226382     0.472594
# 108       0.226382     0.472594
# 125       0.226382     0.472594
# 137       0.226382     0.472594
# 150       0.226382     0.472594
# 158       0.226382     0.472594
# 171       0.226382     0.472594
# 187       0.226382     0.472594
# 195       0.226382     0.472594
# 220       0.226382     0.472594
# 275       0.226382     0.472594
# 284       0.226382     0.472594
# 328       0.226382     0.472594
# 348       0.226382     0.472594
# 373       0.226382     0.472594
# 380       0.226382     0.472594
# 409       0.226382     0.472594
# 465       0.226382     0.472594
# 506       0.226382     0.472594
# 517       0.226382     0.472594
# 530       0.226382     0.472594
# 552       0.226382     0.472594
# 565       0.226382     0.472594
# 569       0.226382     0.472594
# 584       0.226382     0.472594
# ...            ...          ...
# 10710     0.226382     0.472594
# 10727     0.226382     0.472594
# 10731     0.226382     0.472594
# 10747     0.226382     0.472594
# 10753     0.226382     0.472594
# 10788     0.226382     0.472594
# 10811     0.226382     0.472594
# 10818     0.226382     0.472594
# 10849     0.226382     0.472594
# 10860     0.226382     0.472594
# 10871     0.226382     0.472594
# 10892     0.226382     0.472594
# 10894     0.226382     0.472594
# 10907     0.226382     0.472594
# 10973     0.226382     0.472594
# 10983     0.226382     0.472594
# 10997     0.226382     0.472594
# 11060     0.226382     0.472594
# 11082     0.226382     0.472594
# 11104     0.226382     0.472594
# 11131     0.226382     0.472594
# 11158     0.226382     0.472594
# 11174     0.226382     0.472594
# 11186     0.226382     0.472594
# 11191     0.226382     0.472594
# 11235     0.226382     0.472594
# 11240     0.226382     0.472594
# 11249     0.226382     0.472594
# 11289     0.226382     0.472594
# 11312     0.226382     0.472594
#
#                                                     text          group
# 3      From: jgreen@amber (Joe Green)\nSubject: Re: W...  comp.graphics
# 16     From: ab@nova.cc.purdue.edu (Allen B)\nSubject...  comp.graphics
# 25     From: kph2q@onyx.cs.Virginia.EDU (Kenneth Hinc...  comp.graphics
# 82     From: edb@dmssyd.syd.dms.CSIRO.AU (Ed Breen)\n...  comp.graphics
# 87     From: beck@irzr17.inf.tu-dresden.de (Andre Bec...  comp.graphics
# 99     From: tmc@spartan.ac.BrockU.CA (Tim Ciceran)\n...  comp.graphics
# 108    From: pallis@server.uwindsor.ca (PALLIS  DIMIT...  comp.graphics
# 125    From: joachim@kih.no (joachim lous)\nSubject: ...  comp.graphics
# 137    From: seth@north1.acpub.duke.edu (Seth Wanders...  comp.graphics
# 150    From: weston@ucssun1.sdsu.edu (weston t)\nSubj...  comp.graphics
# 158    From: thester@nyx.cs.du.edu (Uncle Fester)\nSu...  comp.graphics
# 171    From: bryanw@rahul.net (Bryan Woodworth)\nSubj...  comp.graphics
# 187    From: johnsh@rpi.edu (Hugh Johnson)\nSubject: ...  comp.graphics
# 195    Subject: XV under MS-DOS ?!?\nFrom: NO E-MAIL ...  comp.graphics
# 220    From: andreasa@dhhalden.no (ANDREAS ARFF)\nSub...  comp.graphics
# 275    From: dingebre@imp.sim.es.com (David Ingebrets...  comp.graphics
# 284    From: fineman@stein2.u.washington.edu (Twixt y...  comp.graphics
# 328    From: joachim@kih.no (joachim lous)\nSubject: ...  comp.graphics
# 348    From: ARowatt@massey.ac.nz (A.J. Rowatt)\nSubj...  comp.graphics
# 373    From: bob@black.ox.ac.uk (Bob Douglas)\nSubjec...  comp.graphics
# 380    From: g.coulter@daresbury.ac.uk (G. Coulter)\n...  comp.graphics
# 409    From: edb9140@tamsun.tamu.edu (E.B.)\nSubject:...  comp.graphics
# 465    From: ferdinan@oeinck.waterland.wlink.nl (Ferd...  comp.graphics
# 506    From: un034214@wvnvms.wvnet.edu\nSubject: M-MO...  comp.graphics
# 517    From: trb3@Ra.MsState.Edu (Tony R. Boutwell)\n...  comp.graphics
# 530    From: ezzie@lucs2.lancs.ac.uk (One of those da...  comp.graphics
# 552    From: mccool@dgp.toronto.edu (Michael McCool)\...  comp.graphics
# 565    From: spl@dim.ucsd.edu (Steve Lamont)\nSubject...  comp.graphics
# 569    From: stgprao@st.unocal.COM (Richard Ottolini)...  comp.graphics
# 584    From: schaefer@imag.imag.fr (Arno Schaefer)\nS...  comp.graphics
# ...                                                  ...            ...
# 10710  From: robert@cpuserver.acsc.com (Robert Grant)...  comp.graphics
# 10727  From: hintmatt@cwis.isu.edu (HINTZE_MATTHEW)\n...  comp.graphics
# 10731  From: lm001@rrz.Uni-Koeln.DE (Erwin H. Keeve)\...  comp.graphics
# 10747  From: clldomps@cs.ruu.nl (Louis van Dompselaar...  comp.graphics
# 10753  From: diablo.UUCP!cboesel (Charles Boesel)\nSu...  comp.graphics
# 10788  From: patrick@Erc.MsState.Edu (Patrick Bridges...  comp.graphics
# 10811  From: kohut1@urz.unibas.ch\nSubject: Help ! Mi...  comp.graphics
# 10818  From: eylerken@stein.u.washington.edu (Ken Eyl...  comp.graphics
# 10849  From: gmt@beach.cis.ufl.edu (Gary McTaggart)\n...  comp.graphics
# 10860  From: osprey@ux4.cso.uiuc.edu (Lucas Adamski)\...  comp.graphics
# 10871  From: rschmitt@shearson.com (Robert Schmitt)\n...  comp.graphics
# 10892  From: steve@hcrlgw (Steven Collins)\nSubject: ...  comp.graphics
# 10894  From: ldawes@uahcs2.cs.uah.edu (Lisa Dawes)\nS...  comp.graphics
# 10907  From: ib@ivan.asd.sgi.com (Ivan Bach)\nSubject...  comp.graphics
# 10973  From: newmme@helios.tn.cornell.edu (Mark E. J....  comp.graphics
# 10983  From: scott@osi.com (Scott Fleming)\nSubject: ...  comp.graphics
# 10997  From: rgc3679@bcstec.ca.boeing.com (Robert G. ...  comp.graphics
# 11060  From: mmadsen@bonnie.ics.uci.edu (Matt Madsen)...  comp.graphics
# 11082  From: rah13@cunixb.cc.columbia.edu (Robert A H...  comp.graphics
# 11104  From:  Valentin E. Vulihman <vulih@ipmce.su>\n...  comp.graphics
# 11131  Subject: Re: Looking for Tseng VESA drivers\nF...  comp.graphics
# 11158  Subject: Re: Video in/out\nFrom: djlewis@ualr....  comp.graphics
# 11174  From: eylerken@stein.u.washington.edu (Ken Eyl...  comp.graphics
# 11186  From: kewe@bskewe.atr.bso.nl (Cornelis Wessels...  comp.graphics
# 11191  From: boebert@sctc.com (Earl Boebert)\nSubject...  comp.graphics
# 11235  From: tmc@spartan.ac.BrockU.CA (Tim Ciceran)\n...  comp.graphics
# 11240  From: dsnyder@falcon.aamrl.wpafb.af.mil\nSubje...  comp.graphics
# 11249  From: borst@cs.utwente.nl (Pim Borst)\nSubject...  comp.graphics
# 11289  From: max@slinky.NYU.EDU (David Max)\nSubject:...  comp.graphics
# 11312  From: steve@hcrlgw (Steven Collins)\nSubject: ...  comp.graphics
#
# [584 rows x 4 columns]

# %%
document_term_matrix.head()
# Out:
#                        alt  atheism     autos  baseball  christian      comp  \
# group
# rec.autos              0.0      0.0  0.839378       0.0        0.0  0.000000
# comp.sys.mac.hardware  0.0      0.0  0.000000       0.0        0.0  0.359505
# comp.sys.mac.hardware  0.0      0.0  0.000000       0.0        0.0  0.359505
# comp.graphics          0.0      0.0  0.000000       0.0        0.0  0.509919
# sci.space              0.0      0.0  0.000000       0.0        0.0  0.000000
#
#                        crypt  electronics  forsale  graphics   ...     \
# group                                                          ...
# rec.autos                0.0          0.0      0.0  0.000000   ...
# comp.sys.mac.hardware    0.0          0.0      0.0  0.000000   ...
# comp.sys.mac.hardware    0.0          0.0      0.0  0.000000   ...
# comp.graphics            0.0          0.0      0.0  0.860222   ...
# sci.space                0.0          0.0      0.0  0.000000   ...
#
#                        politics       rec  religion       sci  soc     space  \
# group
# rec.autos                   0.0  0.543548       0.0  0.000000  0.0  0.000000
# comp.sys.mac.hardware       0.0  0.000000       0.0  0.000000  0.0  0.000000
# comp.sys.mac.hardware       0.0  0.000000       0.0  0.000000  0.0  0.000000
# comp.graphics               0.0  0.000000       0.0  0.000000  0.0  0.000000
# sci.space                   0.0  0.000000       0.0  0.544391  0.0  0.838832
#
#                        sport       sys  talk  windows
# group
# rec.autos                0.0  0.000000   0.0      0.0
# comp.sys.mac.hardware    0.0  0.500513   0.0      0.0
# comp.sys.mac.hardware    0.0  0.500513   0.0      0.0
# comp.graphics            0.0  0.000000   0.0      0.0
# sci.space                0.0  0.000000   0.0      0.0
#
# [5 rows x 32 columns]

# %%
dtm_corr = document_term_matrix.corr()
dtm_corr.head()
# Out:
#                 alt   atheism     autos  baseball  christian      comp  \
# alt        1.000000  1.000000 -0.049548 -0.049679  -0.049767 -0.118964
# atheism    1.000000  1.000000 -0.049548 -0.049679  -0.049767 -0.118964
# autos     -0.049548 -0.049548  1.000000 -0.055558  -0.055656 -0.133041
# baseball  -0.049679 -0.049679 -0.055558  1.000000  -0.055804 -0.133395
# christian -0.049767 -0.049767 -0.055656 -0.055804   1.000000 -0.133631
#
#               crypt  electronics   forsale  graphics    ...     politics  \
# alt       -0.049592    -0.049415 -0.049150 -0.049106    ...    -0.084385
# atheism   -0.049592    -0.049415 -0.049150 -0.049106    ...    -0.084385
# autos     -0.055460    -0.055263 -0.054966 -0.054916    ...    -0.094371
# baseball  -0.055607    -0.055410 -0.055112 -0.055063    ...    -0.094622
# christian -0.055706    -0.055508 -0.055210 -0.055160    ...    -0.094789
#
#                 rec  religion       sci       soc     space     sport  \
# alt       -0.108257 -0.064203 -0.108438 -0.049767 -0.049503 -0.072401
# atheism   -0.108257 -0.064203 -0.108438 -0.049767 -0.049503 -0.072401
# autos      0.507656 -0.071800 -0.121270 -0.055656 -0.055361 -0.080969
# baseball   0.397676 -0.071992 -0.121592 -0.055804 -0.055509  0.685933
# christian -0.121603  0.686946 -0.121807  1.000000 -0.055607 -0.081328
#
#                 sys      talk   windows
# alt       -0.071181 -0.095849 -0.068672
# atheism   -0.071181 -0.095849 -0.068672
# autos     -0.079604 -0.107190 -0.076798
# baseball  -0.079816 -0.107476 -0.077002
# christian -0.079957 -0.107666 -0.077138
#
# [5 rows x 32 columns]

# %%
mask = np.zeros_like(dtm_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
fig = plt.figure(figsize=(30,30))
sns.heatmap(dtm_corr, mask=mask)
